# %% [markdown]
# # **Scraping Articles from U.S. Library of Congress database, "Chronicling America"**
# This database contains America's historic newspaper pages from 1789-1963.  We'll be searching for the phrase "spanish flu"

# %% [markdown]
# ## __Setup__

# %%
# !pip install wget
import wget
import requests
import json
import os
import pandas as pd

# %%
#Point to file location on Google Drive
import os
from google.colab import drive

drive.mount('/content/gdrive', force_remount=True)
root = os.getcwd()
download_destination = 'gdrive/My Drive/COVID-19/data/spanish_flu_data'
cwd = os.path.join(root, download_destination)
os.chdir(cwd)
print('Current working directory: ', os.getcwd())

# %% [markdown]
# ## __Scraping__
#
# We'll now define the function that will scrape a single page,and then cycle through each page in the search to gather all relevant articles.  Note that if you'd like to search for a different phrase, then you can modify the (long) URL in the second code cell down.

# %% [markdown]
# ##**Getting PDFs**
# We'll get the PDFs here, so that we can run them through our own OCR.

# %%
#Download files for a single search results page
Base_URL = "https://chroniclingamerica.loc.gov"
def get_pdf(ids, format='pdf'):
    article_metadata = []
    for id in ids:
        current_article = {}
        
        #Build and query url, and split results as metadata
        url = Base_URL+id[:-1]+'.json'
        resp = requests.get(url) #get download options
        pdf_url = requests.get(resp.json()[format]) #download url
        
        #Save metadata
        split_url = id.split('/')
        current_article['id'] = split_url[2]
        current_article['date_issued'] = split_url[3]
        current_article['ed'] = split_url[4]
        current_article['seq'] = split_url[5]
        current_article['paper'] = resp.json()['title']['name']
        
        #Download the PDF
        pdf_name = ''.join((current_article['id'], '.pdf'))
        if not os.path.isfile(filename):
            open(pdf_name, 'wb').write(pdf_url.content)
            article_metadata.append(current_article)
    
    return article_metadata

# articles = get_pdf(ids)
# print('Number of articles retrieved: ', len(article_metadata))

# %%
num_results = 320
page_increment = 1
results_per_page = 50

import pandas as pd

metadata = pd.DataFrame()

for page_num in range(1, num_results, page_increment):
    search_URL = "https://chroniclingamerica.loc.gov/search/pages/results/?date1=1918&sort=relevance&date2=1920&searchType=basic&sequence=0&format=json&state=&rows={}&proxtext=spanish+flu&y=50&x=14&dateFilterType=yearRange&page={}".format(results_per_page, page_num)
    resp = requests.get(search_URL)
    results = resp.json()

    for idx, article in enumerate(results['items']):
        temp = pd.Series(article, name=idx)
        metadata = metadata.append(temp)
        
metadata.to_pickle('metadata.pkl')

# %%
metadata.head()
# Out:
#                                     alt_title                batch  \
# 0                                          []    msar_garnet_ver01
# 1  [Evening journal and the daily Republican]  deu_hockessin_ver01
# 2                          [Omaha Sunday bee]  nbu_coreopsis_ver01
# 3                   [Washington times herald]    dlc_jetblue_ver01
# 4                                          []       kyu_gold_ver01
#
#              city               country        county      date  \
# 0  [Water Valley]           Mississippi   [Yalobusha]  19181108
# 1    [Wilmington]              Delaware  [New Castle]  19181017
# 2         [Omaha]              Nebraska     [Douglas]  19181009
# 3    [Washington]  District of Columbia        [None]  19181029
# 4         [Paris]              Kentucky     [Bourbon]  19181022
#
#           edition  edition_label  end_year              frequency  ...  \
# 0            None                   1929.0                 Weekly  ...
# 1            None                   1932.0    Daily (except Sun.)  ...
# 2  [Morning ed.].                   1922.0                  Daily  ...
# 3            None  FINAL EDITION    1939.0  Daily (except Sunday)  ...
# 4            None                   1999.0             Semiweekly  ...
#
#    section_label sequence start_year                   state  \
# 0                     7.0     1888.0           [Mississippi]
# 1                     8.0     1888.0              [Delaware]
# 2                     5.0     1870.0              [Nebraska]
# 3  SPORTING PAGE     14.0     1902.0  [District of Columbia]
# 4                     2.0     1895.0              [Kentucky]
#
#                                              subject  \
# 0  [Mississippi--Water Valley.--fast--(OCoLC)fst0...
# 1  [Delaware--Wilmington.--fast--(OCoLC)fst012039...
# 2  [Nebraska--Omaha.--fast--(OCoLC)fst01204995, O...
# 3  [Washington (D.C.)--fast--(OCoLC)fst01204505, ...
# 4  [Bourbon County (Ky.)--Newspapers., Kentucky--...
#
#                             title               title_normal  type  \
# 0   The North Mississippi herald.  north mississippi herald.  page
# 1       Evening journal. [volume]           evening journal.  page
# 2                Omaha daily bee.           omaha daily bee.  page
# 3  The Washington times. [volume]          washington times.  page
# 4      The Bourbon news. [volume]              bourbon news.  page
#
#                                                  url ocr_spa
# 0  https://chroniclingamerica.loc.gov/lccn/sn8706...     NaN
# 1  https://chroniclingamerica.loc.gov/lccn/sn8504...     NaN
# 2  https://chroniclingamerica.loc.gov/lccn/sn9902...     NaN
# 3  https://chroniclingamerica.loc.gov/lccn/sn8402...     NaN
# 4  https://chroniclingamerica.loc.gov/lccn/sn8606...     NaN
#
# [5 rows x 29 columns]

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15946 entries, 0 to 49
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   alt_title             15946 non-null  object
#  1   batch                 15946 non-null  object
#  2   city                  15946 non-null  object
#  3   country               15946 non-null  object
#  4   county                15946 non-null  object
#  5   date                  15946 non-null  object
#  6   edition               2418 non-null   object
#  7   edition_label         15946 non-null  object
#  8   end_year              15946 non-null  float64
#  9   frequency             15941 non-null  object
#  10  id                    15946 non-null  object
#  11  language              15946 non-null  object
#  12  lccn                  15946 non-null  object
#  13  note                  15946 non-null  object
#  14  ocr_eng               15945 non-null  object
#  15  page                  15946 non-null  object
#  16  place                 15946 non-null  object
#  17  place_of_publication  15946 non-null  object
#  18  publisher             15353 non-null  object
#  19  section_label         15946 non-null  object
#  20  sequence              15946 non-null  float64
#  21  start_year            15946 non-null  float64
#  22  state                 15946 non-null  object
#  23  subject               15946 non-null  object
#  24  title                 15946 non-null  object
#  25  title_normal          15946 non-null  object
#  26  type                  15946 non-null  object
#  27  url                   15946 non-null  object
#  28  ocr_spa               8 non-null      object
# dtypes: float64(3), object(26)
# memory usage: 3.6+ MB

# %%
#Import pickled file
metadata = pd.read_pickle('metadata.pkl')

#Expand rows with list objects so that we can deduplicate
metadata_copy = metadata.copy()
cols_with_lists = []

for col in metadata_copy.columns:
    if isinstance(metadata_copy[col].iloc[0], list):
        cols_with_lists.append(col)
        metadata_copy = metadata_copy.explode(column=col)
        
#Deduplicate rows that didn't have list objects
metadata_copy = metadata_copy.drop_duplicates(subset=[col for col in metadata_copy if col not in cols_with_lists])
metadata_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2196 entries, 0 to 45
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   alt_title             1192 non-null   object
#  1   batch                 2196 non-null   object
#  2   city                  2196 non-null   object
#  3   country               2196 non-null   object
#  4   county                2062 non-null   object
#  5   date                  2196 non-null   object
#  6   edition               218 non-null    object
#  7   edition_label         2196 non-null   object
#  8   end_year              2196 non-null   float64
#  9   frequency             2191 non-null   object
#  10  id                    2196 non-null   object
#  11  language              2196 non-null   object
#  12  lccn                  2196 non-null   object
#  13  note                  2181 non-null   object
#  14  ocr_eng               2195 non-null   object
#  15  page                  2196 non-null   object
#  16  place                 2196 non-null   object
#  17  place_of_publication  2196 non-null   object
#  18  publisher             2153 non-null   object
#  19  section_label         2196 non-null   object
#  20  sequence              2196 non-null   float64
#  21  start_year            2196 non-null   float64
#  22  state                 2196 non-null   object
#  23  subject               2163 non-null   object
#  24  title                 2196 non-null   object
#  25  title_normal          2196 non-null   object
#  26  type                  2196 non-null   object
#  27  url                   2196 non-null   object
#  28  ocr_spa               8 non-null      object
# dtypes: float64(3), object(26)
# memory usage: 514.7+ KB

# %%
for lccn, url, article_date, sequence in zip(metadata_copy['lccn'],metadata_copy['url'], metadata_copy['date'], metadata_copy['sequence']):
    resp = requests.get(url)
    pdf_url = resp.json()['pdf']
    
    #Download the PDF
    pdf_name = ''.join((lccn, '_', article_date, '_', str(int(sequence)), '.pdf'))
#     if not os.path.isfile(pdf_name):
    open(pdf_name, 'wb').write(requests.get(pdf_url).content)

# %%
#Download 100 per results at a time and save the text to file in json format
num_results = 320
page_increment = 1
results_per_page = 50


for page_num in range(1, num_results, page_increment):
    #Setup query page, and get url extensions containing persistent IDs
    print('Querying page: ', page_num)
    search_URL = "https://chroniclingamerica.loc.gov/search/pages/results/?date1=1918&rows={}&searchType=basic&format=json&state=&date2=1920&proxtext=spanish+flu&y=50&x=14&dateFilterType=yearRange&page={}&sort=relevance".format(results_per_page, page_num)
    response = requests.get(search_URL)
    data = response.json()
    ids = [i["id"] for i in data["items"]]
    
    #Harvest articles & metadata
    base_URL = "https://chroniclingamerica.loc.gov"
    articles = get_pdf(ids)

    #Save to disk
    filename = ''.join(('Metadata_LOC - ', str(page_num), '_', str(page_num+page_increment), '.json'))
    with open(filename, 'w') as f:
        json.dump(articles, f)
    print('Saved as {}'.format(filename))

    print('{} articles harvested!'.format(len(articles)))
# Out:
# Querying page:  1
# Saved as Metadata_LOC - 1_2.json
# 0 articles harvested!
# Querying page:  2
# Saved as Metadata_LOC - 2_3.json
# 0 articles harvested!
# Querying page:  3
# Saved as Metadata_LOC - 3_4.json
# 0 articles harvested!
# Querying page:  4
# Saved as Metadata_LOC - 4_5.json
# 0 articles harvested!
# Querying page:  5
# Saved as Metadata_LOC - 5_6.json
# 0 articles harvested!
# Querying page:  6
# Saved as Metadata_LOC - 6_7.json
# 0 articles harvested!
# Querying page:  7
# Saved as Metadata_LOC - 7_8.json
# 0 articles harvested!
# Querying page:  8
# Saved as Metadata_LOC - 8_9.json
# 0 articles harvested!
# Querying page:  9
# Saved as Metadata_LOC - 9_10.json
# 0 articles harvested!
# Querying page:  10
# Saved as Metadata_LOC - 10_11.json
# 0 articles harvested!
# Querying page:  11
# Saved as Metadata_LOC - 11_12.json
# 0 articles harvested!
# Querying page:  12
# Saved as Metadata_LOC - 12_13.json
# 0 articles harvested!
# Querying page:  13
# Saved as Metadata_LOC - 13_14.json
# 0 articles harvested!
# Querying page:  14
# Saved as Metadata_LOC - 14_15.json
# 0 articles harvested!
# Querying page:  15
# Saved as Metadata_LOC - 15_16.json
# 0 articles harvested!
# Querying page:  16
# Saved as Metadata_LOC - 16_17.json
# 0 articles harvested!
# Querying page:  17
# Saved as Metadata_LOC - 17_18.json
# 0 articles harvested!
# Querying page:  18
# Saved as Metadata_LOC - 18_19.json
# 0 articles harvested!
# Querying page:  19
# Saved as Metadata_LOC - 19_20.json
# 0 articles harvested!
# Querying page:  20
# Saved as Metadata_LOC - 20_21.json
# 0 articles harvested!
# Querying page:  21
# Saved as Metadata_LOC - 21_22.json
# 0 articles harvested!
# Querying page:  22
# Saved as Metadata_LOC - 22_23.json
# 0 articles harvested!
# Querying page:  23
# Saved as Metadata_LOC - 23_24.json
# 0 articles harvested!
# Querying page:  24
# Saved as Metadata_LOC - 24_25.json
# 0 articles harvested!
# Querying page:  25
# Saved as Metadata_LOC - 25_26.json
# 0 articles harvested!
# Querying page:  26
# Saved as Metadata_LOC - 26_27.json
# 0 articles harvested!
# Querying page:  27
# Saved as Metadata_LOC - 27_28.json
# 0 articles harvested!
# Querying page:  28
# Saved as Metadata_LOC - 28_29.json
# 0 articles harvested!
# Querying page:  29
# Saved as Metadata_LOC - 29_30.json
# 0 articles harvested!
# Querying page:  30
# Saved as Metadata_LOC - 30_31.json
# 0 articles harvested!
# Querying page:  31
# Saved as Metadata_LOC - 31_32.json
# 0 articles harvested!
# Querying page:  32
# Saved as Metadata_LOC - 32_33.json
# 0 articles harvested!
# Querying page:  33
# Saved as Metadata_LOC - 33_34.json
# 0 articles harvested!
# Querying page:  34
# Saved as Metadata_LOC - 34_35.json
# 0 articles harvested!
# Querying page:  35
# Saved as Metadata_LOC - 35_36.json
# 0 articles harvested!
# Querying page:  36
# Saved as Metadata_LOC - 36_37.json
# 0 articles harvested!
# Querying page:  37
# Saved as Metadata_LOC - 37_38.json
# 0 articles harvested!
# Querying page:  38
# Saved as Metadata_LOC - 38_39.json
# 0 articles harvested!
# Querying page:  39
# Saved as Metadata_LOC - 39_40.json
# 0 articles harvested!
# Querying page:  40
# Saved as Metadata_LOC - 40_41.json
# 0 articles harvested!
# Querying page:  41
# Saved as Metadata_LOC - 41_42.json
# 0 articles harvested!
# Querying page:  42
# Saved as Metadata_LOC - 42_43.json
# 0 articles harvested!
# Querying page:  43
# Saved as Metadata_LOC - 43_44.json
# 0 articles harvested!
# Querying page:  44
# Saved as Metadata_LOC - 44_45.json
# 0 articles harvested!
# Querying page:  45
# Saved as Metadata_LOC - 45_46.json
# 0 articles harvested!
# Querying page:  46
# Saved as Metadata_LOC - 46_47.json
# 0 articles harvested!
# Querying page:  47
# Saved as Metadata_LOC - 47_48.json
# 0 articles harvested!
# Querying page:  48
# Saved as Metadata_LOC - 48_49.json
# 0 articles harvested!
# Querying page:  49
# Saved as Metadata_LOC - 49_50.json
# 0 articles harvested!
# Querying page:  50
# Saved as Metadata_LOC - 50_51.json
# 0 articles harvested!
# Querying page:  51
# Saved as Metadata_LOC - 51_52.json
# 0 articles harvested!
# Querying page:  52
# Saved as Metadata_LOC - 52_53.json
# 0 articles harvested!
# Querying page:  53
# Saved as Metadata_LOC - 53_54.json
# 0 articles harvested!
# Querying page:  54
# Saved as Metadata_LOC - 54_55.json
# 0 articles harvested!
# Querying page:  55
# Saved as Metadata_LOC - 55_56.json
# 0 articles harvested!
# Querying page:  56
# Saved as Metadata_LOC - 56_57.json
# 0 articles harvested!
# Querying page:  57
# Saved as Metadata_LOC - 57_58.json
# 0 articles harvested!
# Querying page:  58
# Saved as Metadata_LOC - 58_59.json
# 0 articles harvested!
# Querying page:  59
# Saved as Metadata_LOC - 59_60.json
# 0 articles harvested!
# Querying page:  60
# Saved as Metadata_LOC - 60_61.json
# 0 articles harvested!
# Querying page:  61
# Saved as Metadata_LOC - 61_62.json
# 0 articles harvested!
# Querying page:  62
# Saved as Metadata_LOC - 62_63.json
# 0 articles harvested!
# Querying page:  63
# Saved as Metadata_LOC - 63_64.json
# 0 articles harvested!
# Querying page:  64
# Saved as Metadata_LOC - 64_65.json
# 0 articles harvested!
# Querying page:  65
# Saved as Metadata_LOC - 65_66.json
# 0 articles harvested!
# Querying page:  66
# Saved as Metadata_LOC - 66_67.json
# 0 articles harvested!
# Querying page:  67
# Saved as Metadata_LOC - 67_68.json
# 0 articles harvested!
# Querying page:  68
# Saved as Metadata_LOC - 68_69.json
# 0 articles harvested!
# Querying page:  69
# Saved as Metadata_LOC - 69_70.json
# 0 articles harvested!
# Querying page:  70
# Saved as Metadata_LOC - 70_71.json
# 0 articles harvested!
# Querying page:  71
# Saved as Metadata_LOC - 71_72.json
# 0 articles harvested!
# Querying page:  72
# Saved as Metadata_LOC - 72_73.json
# 0 articles harvested!
# Querying page:  73
# Saved as Metadata_LOC - 73_74.json
# 0 articles harvested!
# Querying page:  74
# Saved as Metadata_LOC - 74_75.json
# 0 articles harvested!
# Querying page:  75
# Saved as Metadata_LOC - 75_76.json
# 0 articles harvested!
# Querying page:  76
# Saved as Metadata_LOC - 76_77.json
# 0 articles harvested!
# Querying page:  77
# Saved as Metadata_LOC - 77_78.json
# 0 articles harvested!
# Querying page:  78
# Saved as Metadata_LOC - 78_79.json
# 0 articles harvested!
# Querying page:  79
# Saved as Metadata_LOC - 79_80.json
# 0 articles harvested!
# Querying page:  80
# Saved as Metadata_LOC - 80_81.json
# 0 articles harvested!
# Querying page:  81
# Saved as Metadata_LOC - 81_82.json
# 0 articles harvested!
# Querying page:  82
# Saved as Metadata_LOC - 82_83.json
# 0 articles harvested!
# Querying page:  83
# Saved as Metadata_LOC - 83_84.json
# 0 articles harvested!
# Querying page:  84
# Saved as Metadata_LOC - 84_85.json
# 0 articles harvested!
# Querying page:  85
# Saved as Metadata_LOC - 85_86.json
# 0 articles harvested!
# Querying page:  86
# Saved as Metadata_LOC - 86_87.json
# 0 articles harvested!
# Querying page:  87
# Saved as Metadata_LOC - 87_88.json
# 0 articles harvested!
# Querying page:  88
# Saved as Metadata_LOC - 88_89.json
# 0 articles harvested!
# Querying page:  89
# Saved as Metadata_LOC - 89_90.json
# 0 articles harvested!
# Querying page:  90
# Saved as Metadata_LOC - 90_91.json
# 0 articles harvested!
# Querying page:  91
# Saved as Metadata_LOC - 91_92.json
# 0 articles harvested!
# Querying page:  92
# Saved as Metadata_LOC - 92_93.json
# 0 articles harvested!
# Querying page:  93
# Saved as Metadata_LOC - 93_94.json
# 0 articles harvested!
# Querying page:  94
# Saved as Metadata_LOC - 94_95.json
# 0 articles harvested!
# Querying page:  95
# Saved as Metadata_LOC - 95_96.json
# 0 articles harvested!
# Querying page:  96
# Saved as Metadata_LOC - 96_97.json
# 0 articles harvested!
# Querying page:  97
# Saved as Metadata_LOC - 97_98.json
# 0 articles harvested!
# Querying page:  98
# Saved as Metadata_LOC - 98_99.json
# 0 articles harvested!
# Querying page:  99
# Saved as Metadata_LOC - 99_100.json
# 0 articles harvested!
# Querying page:  100
# Saved as Metadata_LOC - 100_101.json
# 0 articles harvested!
# Querying page:  101
# Saved as Metadata_LOC - 101_102.json
# 0 articles harvested!
# Querying page:  102
# Saved as Metadata_LOC - 102_103.json
# 0 articles harvested!
# Querying page:  103
# Saved as Metadata_LOC - 103_104.json
# 0 articles harvested!
# Querying page:  104
# Saved as Metadata_LOC - 104_105.json
# 0 articles harvested!
# Querying page:  105
# Saved as Metadata_LOC - 105_106.json
# 0 articles harvested!
# Querying page:  106
# Saved as Metadata_LOC - 106_107.json
# 0 articles harvested!
# Querying page:  107
# Saved as Metadata_LOC - 107_108.json
# 0 articles harvested!
# Querying page:  108
# Saved as Metadata_LOC - 108_109.json
# 0 articles harvested!
# Querying page:  109
# Saved as Metadata_LOC - 109_110.json
# 0 articles harvested!
# Querying page:  110
# Saved as Metadata_LOC - 110_111.json
# 0 articles harvested!
# Querying page:  111
# Saved as Metadata_LOC - 111_112.json
# 0 articles harvested!
# Querying page:  112
# Saved as Metadata_LOC - 112_113.json
# 0 articles harvested!
# Querying page:  113
# Saved as Metadata_LOC - 113_114.json
# 0 articles harvested!
# Querying page:  114
# Saved as Metadata_LOC - 114_115.json
# 0 articles harvested!
# Querying page:  115
# Saved as Metadata_LOC - 115_116.json
# 0 articles harvested!
# Querying page:  116
# Saved as Metadata_LOC - 116_117.json
# 0 articles harvested!
# Querying page:  117
# Saved as Metadata_LOC - 117_118.json
# 0 articles harvested!
# Querying page:  118
# Saved as Metadata_LOC - 118_119.json
# 0 articles harvested!
# Querying page:  119
# Saved as Metadata_LOC - 119_120.json
# 0 articles harvested!
# Querying page:  120
# Saved as Metadata_LOC - 120_121.json
# 0 articles harvested!
# Querying page:  121
# Saved as Metadata_LOC - 121_122.json
# 0 articles harvested!
# Querying page:  122
# Saved as Metadata_LOC - 122_123.json
# 0 articles harvested!
# Querying page:  123
# Saved as Metadata_LOC - 123_124.json
# 0 articles harvested!
# Querying page:  124
# Saved as Metadata_LOC - 124_125.json
# 0 articles harvested!
# Querying page:  125
# Saved as Metadata_LOC - 125_126.json
# 0 articles harvested!
# Querying page:  126
# Saved as Metadata_LOC - 126_127.json
# 0 articles harvested!
# Querying page:  127
# Saved as Metadata_LOC - 127_128.json
# 0 articles harvested!
# Querying page:  128
# Saved as Metadata_LOC - 128_129.json
# 0 articles harvested!
# Querying page:  129
# Saved as Metadata_LOC - 129_130.json
# 0 articles harvested!
# Querying page:  130
# Saved as Metadata_LOC - 130_131.json
# 0 articles harvested!
# Querying page:  131
# Saved as Metadata_LOC - 131_132.json
# 0 articles harvested!
# Querying page:  132
# Saved as Metadata_LOC - 132_133.json
# 0 articles harvested!
# Querying page:  133
# Saved as Metadata_LOC - 133_134.json
# 0 articles harvested!
# Querying page:  134
# Saved as Metadata_LOC - 134_135.json
# 0 articles harvested!
# Querying page:  135
# Saved as Metadata_LOC - 135_136.json
# 0 articles harvested!
# Querying page:  136
# Saved as Metadata_LOC - 136_137.json
# 0 articles harvested!
# Querying page:  137
# Saved as Metadata_LOC - 137_138.json
# 0 articles harvested!
# Querying page:  138
# Saved as Metadata_LOC - 138_139.json
# 0 articles harvested!
# Querying page:  139
# Saved as Metadata_LOC - 139_140.json
# 0 articles harvested!
# Querying page:  140
# Saved as Metadata_LOC - 140_141.json
# 0 articles harvested!
# Querying page:  141
# Saved as Metadata_LOC - 141_142.json
# 0 articles harvested!
# Querying page:  142
# Saved as Metadata_LOC - 142_143.json
# 0 articles harvested!
# Querying page:  143
# Saved as Metadata_LOC - 143_144.json
# 0 articles harvested!
# Querying page:  144
# Saved as Metadata_LOC - 144_145.json
# 0 articles harvested!
# Querying page:  145
# Saved as Metadata_LOC - 145_146.json
# 0 articles harvested!
# Querying page:  146
# Saved as Metadata_LOC - 146_147.json
# 0 articles harvested!
# Querying page:  147
# Saved as Metadata_LOC - 147_148.json
# 0 articles harvested!
# Querying page:  148
# Saved as Metadata_LOC - 148_149.json
# 0 articles harvested!
# Querying page:  149
# Saved as Metadata_LOC - 149_150.json
# 0 articles harvested!
# Querying page:  150
# Saved as Metadata_LOC - 150_151.json
# 0 articles harvested!
# Querying page:  151
# Saved as Metadata_LOC - 151_152.json
# 0 articles harvested!
# Querying page:  152
# Saved as Metadata_LOC - 152_153.json
# 0 articles harvested!
# Querying page:  153
# Saved as Metadata_LOC - 153_154.json
# 0 articles harvested!
# Querying page:  154
# Saved as Metadata_LOC - 154_155.json
# 0 articles harvested!
# Querying page:  155
# Saved as Metadata_LOC - 155_156.json
# 0 articles harvested!
# Querying page:  156
# Saved as Metadata_LOC - 156_157.json
# 0 articles harvested!
# Querying page:  157
# Saved as Metadata_LOC - 157_158.json
# 0 articles harvested!
# Querying page:  158
# Saved as Metadata_LOC - 158_159.json
# 0 articles harvested!
# Querying page:  159
# Saved as Metadata_LOC - 159_160.json
# 0 articles harvested!
# Querying page:  160
# Saved as Metadata_LOC - 160_161.json
# 0 articles harvested!
# Querying page:  161
# Saved as Metadata_LOC - 161_162.json
# 0 articles harvested!
# Querying page:  162
# Saved as Metadata_LOC - 162_163.json
# 0 articles harvested!
# Querying page:  163
# Saved as Metadata_LOC - 163_164.json
# 0 articles harvested!
# Querying page:  164
# Saved as Metadata_LOC - 164_165.json
# 0 articles harvested!
# Querying page:  165
# Saved as Metadata_LOC - 165_166.json
# 0 articles harvested!
# Querying page:  166
# Saved as Metadata_LOC - 166_167.json
# 0 articles harvested!
# Querying page:  167
# Saved as Metadata_LOC - 167_168.json
# 0 articles harvested!
# Querying page:  168
# Saved as Metadata_LOC - 168_169.json
# 0 articles harvested!
# Querying page:  169
# Saved as Metadata_LOC - 169_170.json
# 0 articles harvested!
# Querying page:  170
# Saved as Metadata_LOC - 170_171.json
# 0 articles harvested!
# Querying page:  171
# Saved as Metadata_LOC - 171_172.json
# 0 articles harvested!
# Querying page:  172
# Saved as Metadata_LOC - 172_173.json
# 0 articles harvested!
# Querying page:  173
# Saved as Metadata_LOC - 173_174.json
# 0 articles harvested!
# Querying page:  174
# Saved as Metadata_LOC - 174_175.json
# 0 articles harvested!
# Querying page:  175
# Saved as Metadata_LOC - 175_176.json
# 0 articles harvested!
# Querying page:  176
# Saved as Metadata_LOC - 176_177.json
# 0 articles harvested!
# Querying page:  177
# Saved as Metadata_LOC - 177_178.json
# 0 articles harvested!
# Querying page:  178
# Saved as Metadata_LOC - 178_179.json
# 0 articles harvested!
# Querying page:  179
# Saved as Metadata_LOC - 179_180.json
# 0 articles harvested!
# Querying page:  180
# Saved as Metadata_LOC - 180_181.json
# 0 articles harvested!
# Querying page:  181
# Saved as Metadata_LOC - 181_182.json
# 0 articles harvested!
# Querying page:  182
# Saved as Metadata_LOC - 182_183.json
# 0 articles harvested!
# Querying page:  183
# Saved as Metadata_LOC - 183_184.json
# 0 articles harvested!
# Querying page:  184
# Saved as Metadata_LOC - 184_185.json
# 0 articles harvested!
# Querying page:  185
# Saved as Metadata_LOC - 185_186.json
# 0 articles harvested!
# Querying page:  186
# Saved as Metadata_LOC - 186_187.json
# 0 articles harvested!
# Querying page:  187
# Saved as Metadata_LOC - 187_188.json
# 0 articles harvested!
# Querying page:  188
# Saved as Metadata_LOC - 188_189.json
# 0 articles harvested!
# Querying page:  189
# Saved as Metadata_LOC - 189_190.json
# 0 articles harvested!
# Querying page:  190
# Saved as Metadata_LOC - 190_191.json
# 0 articles harvested!
# Querying page:  191
# Saved as Metadata_LOC - 191_192.json
# 0 articles harvested!
# Querying page:  192
# Saved as Metadata_LOC - 192_193.json
# 0 articles harvested!
# Querying page:  193
# Saved as Metadata_LOC - 193_194.json
# 0 articles harvested!
# Querying page:  194
# Saved as Metadata_LOC - 194_195.json
# 0 articles harvested!
# Querying page:  195
# Saved as Metadata_LOC - 195_196.json
# 0 articles harvested!
# Querying page:  196
# Saved as Metadata_LOC - 196_197.json
# 0 articles harvested!
# Querying page:  197
# Saved as Metadata_LOC - 197_198.json
# 0 articles harvested!
# Querying page:  198
# Saved as Metadata_LOC - 198_199.json
# 0 articles harvested!
# Querying page:  199
# Saved as Metadata_LOC - 199_200.json
# 0 articles harvested!
# Querying page:  200
# Saved as Metadata_LOC - 200_201.json
# 0 articles harvested!
# Querying page:  201
# Saved as Metadata_LOC - 201_202.json
# 0 articles harvested!
# Querying page:  202
# Saved as Metadata_LOC - 202_203.json
# 0 articles harvested!
# Querying page:  203
# Saved as Metadata_LOC - 203_204.json
# 0 articles harvested!
# Querying page:  204
# Saved as Metadata_LOC - 204_205.json
# 0 articles harvested!
# Querying page:  205
# Saved as Metadata_LOC - 205_206.json
# 0 articles harvested!
# Querying page:  206
# Saved as Metadata_LOC - 206_207.json
# 0 articles harvested!
# Querying page:  207
# Saved as Metadata_LOC - 207_208.json
# 0 articles harvested!
# Querying page:  208
# Saved as Metadata_LOC - 208_209.json
# 0 articles harvested!
# Querying page:  209
# Saved as Metadata_LOC - 209_210.json
# 0 articles harvested!
# Querying page:  210
# Saved as Metadata_LOC - 210_211.json
# 0 articles harvested!
# Querying page:  211
# Saved as Metadata_LOC - 211_212.json
# 0 articles harvested!
# Querying page:  212
# Saved as Metadata_LOC - 212_213.json
# 0 articles harvested!
# Querying page:  213
# Saved as Metadata_LOC - 213_214.json
# 0 articles harvested!
# Querying page:  214
# Saved as Metadata_LOC - 214_215.json
# 0 articles harvested!
# Querying page:  215
# Saved as Metadata_LOC - 215_216.json
# 0 articles harvested!
# Querying page:  216
# Saved as Metadata_LOC - 216_217.json
# 0 articles harvested!
# Querying page:  217
# Saved as Metadata_LOC - 217_218.json
# 0 articles harvested!
# Querying page:  218
# Saved as Metadata_LOC - 218_219.json
# 0 articles harvested!
# Querying page:  219
# Saved as Metadata_LOC - 219_220.json
# 0 articles harvested!
# Querying page:  220
# Saved as Metadata_LOC - 220_221.json
# 0 articles harvested!
# Querying page:  221
# Saved as Metadata_LOC - 221_222.json
# 0 articles harvested!
# Querying page:  222
# Saved as Metadata_LOC - 222_223.json
# 0 articles harvested!
# Querying page:  223
# Saved as Metadata_LOC - 223_224.json
# 0 articles harvested!
# Querying page:  224
# Saved as Metadata_LOC - 224_225.json
# 0 articles harvested!
# Querying page:  225
# Saved as Metadata_LOC - 225_226.json
# 0 articles harvested!
# Querying page:  226
# Saved as Metadata_LOC - 226_227.json
# 0 articles harvested!
# Querying page:  227
# Saved as Metadata_LOC - 227_228.json
# 0 articles harvested!
# Querying page:  228
# Saved as Metadata_LOC - 228_229.json
# 0 articles harvested!
# Querying page:  229
# Saved as Metadata_LOC - 229_230.json
# 0 articles harvested!
# Querying page:  230
# Saved as Metadata_LOC - 230_231.json
# 0 articles harvested!
# Querying page:  231
# Saved as Metadata_LOC - 231_232.json
# 0 articles harvested!
# Querying page:  232
# Saved as Metadata_LOC - 232_233.json
# 0 articles harvested!
# Querying page:  233
# Saved as Metadata_LOC - 233_234.json
# 0 articles harvested!
# Querying page:  234
# Saved as Metadata_LOC - 234_235.json
# 0 articles harvested!
# Querying page:  235
# Saved as Metadata_LOC - 235_236.json
# 0 articles harvested!
# Querying page:  236
# Saved as Metadata_LOC - 236_237.json
# 0 articles harvested!
# Querying page:  237
# Saved as Metadata_LOC - 237_238.json
# 0 articles harvested!
# Querying page:  238
# Saved as Metadata_LOC - 238_239.json
# 0 articles harvested!
# Querying page:  239
# Saved as Metadata_LOC - 239_240.json
# 0 articles harvested!
# Querying page:  240
# Saved as Metadata_LOC - 240_241.json
# 0 articles harvested!
# Querying page:  241
# Saved as Metadata_LOC - 241_242.json
# 0 articles harvested!
# Querying page:  242
# Saved as Metadata_LOC - 242_243.json
# 0 articles harvested!
# Querying page:  243
# Saved as Metadata_LOC - 243_244.json
# 0 articles harvested!
# Querying page:  244
# Saved as Metadata_LOC - 244_245.json
# 0 articles harvested!
# Querying page:  245
# Saved as Metadata_LOC - 245_246.json
# 0 articles harvested!
# Querying page:  246
# Saved as Metadata_LOC - 246_247.json
# 0 articles harvested!
# Querying page:  247
# Saved as Metadata_LOC - 247_248.json
# 0 articles harvested!
# Querying page:  248
# Saved as Metadata_LOC - 248_249.json
# 0 articles harvested!
# Querying page:  249
# Saved as Metadata_LOC - 249_250.json
# 0 articles harvested!
# Querying page:  250
# Saved as Metadata_LOC - 250_251.json
# 0 articles harvested!
# Querying page:  251
# Saved as Metadata_LOC - 251_252.json
# 0 articles harvested!
# Querying page:  252
# Saved as Metadata_LOC - 252_253.json
# 0 articles harvested!
# Querying page:  253
# Saved as Metadata_LOC - 253_254.json
# 0 articles harvested!
# Querying page:  254
# Saved as Metadata_LOC - 254_255.json
# 0 articles harvested!
# Querying page:  255
# Saved as Metadata_LOC - 255_256.json
# 0 articles harvested!
# Querying page:  256
# Saved as Metadata_LOC - 256_257.json
# 0 articles harvested!
# Querying page:  257
# Saved as Metadata_LOC - 257_258.json
# 0 articles harvested!
# Querying page:  258
# Saved as Metadata_LOC - 258_259.json
# 0 articles harvested!
# Querying page:  259
# Saved as Metadata_LOC - 259_260.json
# 0 articles harvested!
# Querying page:  260
# Saved as Metadata_LOC - 260_261.json
# 0 articles harvested!
# Querying page:  261
# Saved as Metadata_LOC - 261_262.json
# 0 articles harvested!
# Querying page:  262
# Saved as Metadata_LOC - 262_263.json
# 0 articles harvested!
# Querying page:  263
# Saved as Metadata_LOC - 263_264.json
# 0 articles harvested!
# Querying page:  264
# Saved as Metadata_LOC - 264_265.json
# 0 articles harvested!
# Querying page:  265
# Saved as Metadata_LOC - 265_266.json
# 0 articles harvested!
# Querying page:  266
# Saved as Metadata_LOC - 266_267.json
# 0 articles harvested!
# Querying page:  267
# Saved as Metadata_LOC - 267_268.json
# 0 articles harvested!
# Querying page:  268
# Saved as Metadata_LOC - 268_269.json
# 0 articles harvested!
# Querying page:  269
# Saved as Metadata_LOC - 269_270.json
# 0 articles harvested!
# Querying page:  270
# Saved as Metadata_LOC - 270_271.json
# 0 articles harvested!
# Querying page:  271
# Saved as Metadata_LOC - 271_272.json
# 0 articles harvested!
# Querying page:  272
# Saved as Metadata_LOC - 272_273.json
# 0 articles harvested!
# Querying page:  273
# Saved as Metadata_LOC - 273_274.json
# 0 articles harvested!
# Querying page:  274
# Saved as Metadata_LOC - 274_275.json
# 0 articles harvested!
# Querying page:  275
# Saved as Metadata_LOC - 275_276.json
# 0 articles harvested!
# Querying page:  276
# Saved as Metadata_LOC - 276_277.json
# 0 articles harvested!
# Querying page:  277
# Saved as Metadata_LOC - 277_278.json
# 0 articles harvested!
# Querying page:  278
# Saved as Metadata_LOC - 278_279.json
# 0 articles harvested!
# Querying page:  279
# Saved as Metadata_LOC - 279_280.json
# 0 articles harvested!
# Querying page:  280
# Saved as Metadata_LOC - 280_281.json
# 0 articles harvested!
# Querying page:  281
# Saved as Metadata_LOC - 281_282.json
# 0 articles harvested!
# Querying page:  282
# Saved as Metadata_LOC - 282_283.json
# 0 articles harvested!
# Querying page:  283
# Saved as Metadata_LOC - 283_284.json
# 0 articles harvested!
# Querying page:  284
# Saved as Metadata_LOC - 284_285.json
# 0 articles harvested!
# Querying page:  285
# Saved as Metadata_LOC - 285_286.json
# 0 articles harvested!
# Querying page:  286
# Saved as Metadata_LOC - 286_287.json
# 0 articles harvested!
# Querying page:  287
# Saved as Metadata_LOC - 287_288.json
# 0 articles harvested!
# Querying page:  288
# Saved as Metadata_LOC - 288_289.json
# 0 articles harvested!
# Querying page:  289
# Saved as Metadata_LOC - 289_290.json
# 0 articles harvested!
# Querying page:  290
# Saved as Metadata_LOC - 290_291.json
# 0 articles harvested!
# Querying page:  291
# Saved as Metadata_LOC - 291_292.json
# 0 articles harvested!
# Querying page:  292
# Saved as Metadata_LOC - 292_293.json
# 0 articles harvested!
# Querying page:  293
# Saved as Metadata_LOC - 293_294.json
# 0 articles harvested!
# Querying page:  294
# Saved as Metadata_LOC - 294_295.json
# 0 articles harvested!
# Querying page:  295
# Saved as Metadata_LOC - 295_296.json
# 0 articles harvested!
# Querying page:  296
# Saved as Metadata_LOC - 296_297.json
# 0 articles harvested!
# Querying page:  297
# Saved as Metadata_LOC - 297_298.json
# 0 articles harvested!
# Querying page:  298
# Saved as Metadata_LOC - 298_299.json
# 0 articles harvested!
# Querying page:  299
# Saved as Metadata_LOC - 299_300.json
# 0 articles harvested!
# Querying page:  300
# Saved as Metadata_LOC - 300_301.json
# 0 articles harvested!
# Querying page:  301
# Saved as Metadata_LOC - 301_302.json
# 0 articles harvested!
# Querying page:  302
# Saved as Metadata_LOC - 302_303.json
# 0 articles harvested!
# Querying page:  303
# Saved as Metadata_LOC - 303_304.json
# 0 articles harvested!
# Querying page:  304
# Saved as Metadata_LOC - 304_305.json
# 0 articles harvested!
# Querying page:  305
# Saved as Metadata_LOC - 305_306.json
# 0 articles harvested!
# Querying page:  306
# Saved as Metadata_LOC - 306_307.json
# 0 articles harvested!
# Querying page:  307
# Saved as Metadata_LOC - 307_308.json
# 0 articles harvested!
# Querying page:  308
# Saved as Metadata_LOC - 308_309.json
# 0 articles harvested!
# Querying page:  309
# Saved as Metadata_LOC - 309_310.json
# 0 articles harvested!
# Querying page:  310
# Saved as Metadata_LOC - 310_311.json
# 0 articles harvested!
# Querying page:  311
# Saved as Metadata_LOC - 311_312.json
# 0 articles harvested!
# Querying page:  312
# Saved as Metadata_LOC - 312_313.json
# 0 articles harvested!
# Querying page:  313
# Saved as Metadata_LOC - 313_314.json
# 0 articles harvested!
# Querying page:  314
# Saved as Metadata_LOC - 314_315.json
# 0 articles harvested!
# Querying page:  315
# Saved as Metadata_LOC - 315_316.json
# 0 articles harvested!
# Querying page:  316
# Saved as Metadata_LOC - 316_317.json
# 0 articles harvested!
# Querying page:  317
# Saved as Metadata_LOC - 317_318.json
# 0 articles harvested!
# Querying page:  318
# Saved as Metadata_LOC - 318_319.json
# 0 articles harvested!
# Querying page:  319
# Saved as Metadata_LOC - 319_320.json
# 0 articles harvested!

# %% [markdown]
# ##**Getting Text**
# With the following code, we'll get the text that Chronicling America secured via their own OCR implementation.

# %%
#Download files for a single search results page
Base_URL = "https://chroniclingamerica.loc.gov"
def get_text(ids):
    articles = []
    for id in ids:
        current_article = {}
        
        #Build and query url, and split results as metadata
        url = Base_URL+id[:-1]+'.json'
        resp = requests.get(url)
        split_url = id.split('/')
        
        #Save metadata
        current_article['id'] = split_url[2]
        current_article['date_issued'] = split_url[3]
        current_article['ed'] = split_url[4]
        current_article['seq'] = split_url[5]
        current_article['paper'] = resp.json()['title']['name']
        
        #Get text
        article_text = requests.get(resp.json()['text'])
        current_article['text'] = article_text.text
        articles.append(current_article)

    return articles

articles = get_text(ids)
print('Number of articles retrieved: ', len(articles))
# Out:
# Number of articles retrieved:  50

# %% [markdown]
# Using the function above, we'll cycle through each page and retrieve the article text and metadata that we need.

# %%
#Download 100 per results at a time and save the text to file in json format
num_results = 320
page_increment = 1
results_per_age = 50

for page_num in range(1, num_results, page_increment):
    #Setup query page, and get url extensions containing persistent IDs
    print('Querying page: ', page_num)
    # search_URL = "https://chroniclingamerica.loc.gov/search/pages/results/?date1=1918&rows={}&searchType=basic&format=json&state=&date2=1920&proxtext=spanish+flu&y=50&x=14&dateFilterType=yearRange&page={}&sort=relevance".format(results_per_page, page_num)
    response = requests.get(search_URL)
    data = response.json()
    ids = [i["id"] for i in data["items"]]
    
    #Harvest articles & metadata
    base_URL = "https://chroniclingamerica.loc.gov"
    articles = get_text(ids)

    #Save to disk
    filename = ''.join(('LOC - ', str(page_num), '_', str(page_num+page_increment), '.json'))
    with open(filename, 'w') as f:
        json.dump(articles, f)
    print('Saved as {}'.format(filename))

    # print('{} articles harvested!'.format(len(articles)))
# Out:
# Querying page:  1
# Saved as LOC - 1_2.json
# Querying page:  2
# Saved as LOC - 2_3.json
# Querying page:  3
# Saved as LOC - 3_4.json
# Querying page:  4
# Saved as LOC - 4_5.json
# Querying page:  5
# Saved as LOC - 5_6.json
# Querying page:  6
# Saved as LOC - 6_7.json
# Querying page:  7
# Saved as LOC - 7_8.json
# Querying page:  8
# Saved as LOC - 8_9.json
# Querying page:  9
# Saved as LOC - 9_10.json
# Querying page:  10
# Saved as LOC - 10_11.json
# Querying page:  11
# Saved as LOC - 11_12.json
# Querying page:  12
# Saved as LOC - 12_13.json
# Querying page:  13
# Saved as LOC - 13_14.json
# Querying page:  14
# Saved as LOC - 14_15.json
# Querying page:  15
# Saved as LOC - 15_16.json
# Querying page:  16
# Saved as LOC - 16_17.json
# Querying page:  17
# Saved as LOC - 17_18.json
# Querying page:  18
# Saved as LOC - 18_19.json
# Querying page:  19
# Saved as LOC - 19_20.json
# Querying page:  20
# Saved as LOC - 20_21.json
# Querying page:  21
# Saved as LOC - 21_22.json
# Querying page:  22
# Saved as LOC - 22_23.json
# Querying page:  23
# Saved as LOC - 23_24.json
# Querying page:  24
# Saved as LOC - 24_25.json
# Querying page:  25
# Saved as LOC - 25_26.json
# Querying page:  26
# Saved as LOC - 26_27.json
# Querying page:  27
# Saved as LOC - 27_28.json
# Querying page:  28
# Saved as LOC - 28_29.json
# Querying page:  29
# Saved as LOC - 29_30.json
# Querying page:  30
# Saved as LOC - 30_31.json
# Querying page:  31
# Saved as LOC - 31_32.json
# Querying page:  32
# Saved as LOC - 32_33.json
# Querying page:  33
# Saved as LOC - 33_34.json
# Querying page:  34
# Saved as LOC - 34_35.json
# Querying page:  35
# Saved as LOC - 35_36.json
# Querying page:  36
# Saved as LOC - 36_37.json
# Querying page:  37
# Saved as LOC - 37_38.json
# Querying page:  38
# Saved as LOC - 38_39.json
# Querying page:  39
# Saved as LOC - 39_40.json
# Querying page:  40
# Saved as LOC - 40_41.json
# Querying page:  41
# Saved as LOC - 41_42.json
# Querying page:  42
# Saved as LOC - 42_43.json
# Querying page:  43
# Saved as LOC - 43_44.json
# Querying page:  44
# Saved as LOC - 44_45.json
# Querying page:  45
# Saved as LOC - 45_46.json
# Querying page:  46
# Saved as LOC - 46_47.json
# Querying page:  47
# Saved as LOC - 47_48.json
# Querying page:  48
# Saved as LOC - 48_49.json
# Querying page:  49
# Saved as LOC - 49_50.json
# Querying page:  50
# Saved as LOC - 50_51.json
# Querying page:  51
# Saved as LOC - 51_52.json
# Querying page:  52
# Saved as LOC - 52_53.json
# Querying page:  53
# Saved as LOC - 53_54.json
# Querying page:  54
# Saved as LOC - 54_55.json
# Querying page:  55
# Saved as LOC - 55_56.json
# Querying page:  56
# Saved as LOC - 56_57.json
# Querying page:  57
# Saved as LOC - 57_58.json
# Querying page:  58
# Saved as LOC - 58_59.json
# Querying page:  59
# Saved as LOC - 59_60.json
# Querying page:  60
# Saved as LOC - 60_61.json
# Querying page:  61
# Saved as LOC - 61_62.json
# Querying page:  62
# Saved as LOC - 62_63.json
# Querying page:  63
# Saved as LOC - 63_64.json
# Querying page:  64
# Saved as LOC - 64_65.json
# Querying page:  65
# Saved as LOC - 65_66.json
# Querying page:  66
# Saved as LOC - 66_67.json
# Querying page:  67
# Saved as LOC - 67_68.json
# Querying page:  68
# Saved as LOC - 68_69.json
# Querying page:  69
# Saved as LOC - 69_70.json
# Querying page:  70
# Saved as LOC - 70_71.json
# Querying page:  71
# Saved as LOC - 71_72.json
# Querying page:  72
# Saved as LOC - 72_73.json
# Querying page:  73
# Saved as LOC - 73_74.json
# Querying page:  74
# Saved as LOC - 74_75.json
# Querying page:  75
# Saved as LOC - 75_76.json
# Querying page:  76
# Saved as LOC - 76_77.json
# Querying page:  77
# Saved as LOC - 77_78.json
# Querying page:  78
# Saved as LOC - 78_79.json
# Querying page:  79
# Saved as LOC - 79_80.json
# Querying page:  80
# Saved as LOC - 80_81.json
# Querying page:  81
# Saved as LOC - 81_82.json
# Querying page:  82
# Saved as LOC - 82_83.json
# Querying page:  83
# Saved as LOC - 83_84.json
# Querying page:  84
# Saved as LOC - 84_85.json
# Querying page:  85
# Saved as LOC - 85_86.json
# Querying page:  86
# Saved as LOC - 86_87.json
# Querying page:  87
# Saved as LOC - 87_88.json
# Querying page:  88
# Saved as LOC - 88_89.json
# Querying page:  89
# Saved as LOC - 89_90.json
# Querying page:  90
# Saved as LOC - 90_91.json
# Querying page:  91
# Saved as LOC - 91_92.json
# Querying page:  92
# Saved as LOC - 92_93.json
# Querying page:  93
# Saved as LOC - 93_94.json
# Querying page:  94
# Saved as LOC - 94_95.json
# Querying page:  95
# Saved as LOC - 95_96.json
# Querying page:  96
# Saved as LOC - 96_97.json
# Querying page:  97
# Saved as LOC - 97_98.json
# Querying page:  98
# Saved as LOC - 98_99.json
# Querying page:  99
# Saved as LOC - 99_100.json
# Querying page:  100
# Saved as LOC - 100_101.json
# Querying page:  101
# Saved as LOC - 101_102.json
# Querying page:  102
# Saved as LOC - 102_103.json
# Querying page:  103
# Saved as LOC - 103_104.json
# Querying page:  104
# Saved as LOC - 104_105.json
# Querying page:  105
# Saved as LOC - 105_106.json
# Querying page:  106
# Saved as LOC - 106_107.json
# Querying page:  107
# Saved as LOC - 107_108.json
# Querying page:  108
# Saved as LOC - 108_109.json
# Querying page:  109
# Saved as LOC - 109_110.json
# Querying page:  110
# Saved as LOC - 110_111.json
# Querying page:  111
# Saved as LOC - 111_112.json
# Querying page:  112
# Saved as LOC - 112_113.json
# Querying page:  113
# Saved as LOC - 113_114.json
# Querying page:  114
# Saved as LOC - 114_115.json
# Querying page:  115
# Saved as LOC - 115_116.json
# Querying page:  116
# Saved as LOC - 116_117.json
# Querying page:  117
# Saved as LOC - 117_118.json
# Querying page:  118
# Saved as LOC - 118_119.json
# Querying page:  119
# Saved as LOC - 119_120.json
# Querying page:  120
# Saved as LOC - 120_121.json
# Querying page:  121
# Saved as LOC - 121_122.json
# Querying page:  122
# Saved as LOC - 122_123.json
# Querying page:  123
# Saved as LOC - 123_124.json
# Querying page:  124
# Saved as LOC - 124_125.json
# Querying page:  125
# Saved as LOC - 125_126.json
# Querying page:  126
# Saved as LOC - 126_127.json
# Querying page:  127
# Saved as LOC - 127_128.json
# Querying page:  128
# Saved as LOC - 128_129.json
# Querying page:  129
# Saved as LOC - 129_130.json
# Querying page:  130
# Saved as LOC - 130_131.json
# Querying page:  131
# Saved as LOC - 131_132.json
# Querying page:  132
# Saved as LOC - 132_133.json
# Querying page:  133
# Saved as LOC - 133_134.json
# Querying page:  134
# Saved as LOC - 134_135.json
# Querying page:  135
# Saved as LOC - 135_136.json
# Querying page:  136
# Saved as LOC - 136_137.json
# Querying page:  137
# Saved as LOC - 137_138.json
# Querying page:  138
# Saved as LOC - 138_139.json
# Querying page:  139
# Saved as LOC - 139_140.json
# Querying page:  140
# Saved as LOC - 140_141.json
# Querying page:  141
# Saved as LOC - 141_142.json
# Querying page:  142
# Saved as LOC - 142_143.json
# Querying page:  143
# Saved as LOC - 143_144.json
# Querying page:  144
# Saved as LOC - 144_145.json
# Querying page:  145
# Saved as LOC - 145_146.json
# Querying page:  146
# Saved as LOC - 146_147.json
# Querying page:  147
# Saved as LOC - 147_148.json
# Querying page:  148
# Saved as LOC - 148_149.json
# Querying page:  149
# Saved as LOC - 149_150.json
# Querying page:  150
# Saved as LOC - 150_151.json
# Querying page:  151
# Saved as LOC - 151_152.json
# Querying page:  152
# Saved as LOC - 152_153.json
# Querying page:  153
# Saved as LOC - 153_154.json
# Querying page:  154
# Saved as LOC - 154_155.json
# Querying page:  155
# Saved as LOC - 155_156.json
# Querying page:  156
# Saved as LOC - 156_157.json
# Querying page:  157
# Saved as LOC - 157_158.json
# Querying page:  158
# Saved as LOC - 158_159.json
# Querying page:  159
# Saved as LOC - 159_160.json
# Querying page:  160
# Saved as LOC - 160_161.json
# Querying page:  161
# Saved as LOC - 161_162.json
# Querying page:  162
# Saved as LOC - 162_163.json
# Querying page:  163
# Saved as LOC - 163_164.json
# Querying page:  164
# Saved as LOC - 164_165.json
# Querying page:  165
# Saved as LOC - 165_166.json
# Querying page:  166
# Saved as LOC - 166_167.json
# Querying page:  167
# Saved as LOC - 167_168.json
# Querying page:  168
# Saved as LOC - 168_169.json
# Querying page:  169
# Saved as LOC - 169_170.json
# Querying page:  170
# Saved as LOC - 170_171.json
# Querying page:  171
# Saved as LOC - 171_172.json
# Querying page:  172
# Saved as LOC - 172_173.json
# Querying page:  173
# Saved as LOC - 173_174.json
# Querying page:  174
# Saved as LOC - 174_175.json
# Querying page:  175
# Saved as LOC - 175_176.json
# Querying page:  176
# Saved as LOC - 176_177.json
# Querying page:  177
# Saved as LOC - 177_178.json
# Querying page:  178
# Saved as LOC - 178_179.json
# Querying page:  179
# Saved as LOC - 179_180.json
# Querying page:  180
# Saved as LOC - 180_181.json
# Querying page:  181
# Saved as LOC - 181_182.json
# Querying page:  182
# Saved as LOC - 182_183.json
# Querying page:  183
# Saved as LOC - 183_184.json
# Querying page:  184
# Saved as LOC - 184_185.json
# Querying page:  185
# Saved as LOC - 185_186.json
# Querying page:  186
# Saved as LOC - 186_187.json
# Querying page:  187
# Saved as LOC - 187_188.json
# Querying page:  188
# Saved as LOC - 188_189.json
# Querying page:  189
# Saved as LOC - 189_190.json
# Querying page:  190
# Saved as LOC - 190_191.json
# Querying page:  191
# Saved as LOC - 191_192.json
# Querying page:  192
# Saved as LOC - 192_193.json
# Querying page:  193
# Saved as LOC - 193_194.json
# Querying page:  194
# Saved as LOC - 194_195.json
# Querying page:  195
# Saved as LOC - 195_196.json
# Querying page:  196
# Saved as LOC - 196_197.json
# Querying page:  197
# Saved as LOC - 197_198.json
# Querying page:  198
# Saved as LOC - 198_199.json
# Querying page:  199
# Saved as LOC - 199_200.json
# Querying page:  200
# Saved as LOC - 200_201.json
# Querying page:  201
# Saved as LOC - 201_202.json
# Querying page:  202
# Saved as LOC - 202_203.json
# Querying page:  203
# Saved as LOC - 203_204.json
# Querying page:  204
# Saved as LOC - 204_205.json
# Querying page:  205
# Saved as LOC - 205_206.json
# Querying page:  206
# Saved as LOC - 206_207.json
# Querying page:  207
# Saved as LOC - 207_208.json
# Querying page:  208
# Saved as LOC - 208_209.json
# Querying page:  209
# Saved as LOC - 209_210.json
# Querying page:  210
# Saved as LOC - 210_211.json
# Querying page:  211
# Saved as LOC - 211_212.json
# Querying page:  212
# Saved as LOC - 212_213.json
# Querying page:  213
# Saved as LOC - 213_214.json
# Querying page:  214
# Saved as LOC - 214_215.json
# Querying page:  215
# Saved as LOC - 215_216.json
# Querying page:  216
# Saved as LOC - 216_217.json
# Querying page:  217
# Saved as LOC - 217_218.json
# Querying page:  218
# Saved as LOC - 218_219.json
# Querying page:  219
# Saved as LOC - 219_220.json
# Querying page:  220
# Saved as LOC - 220_221.json
# Querying page:  221
# Saved as LOC - 221_222.json
# Querying page:  222
# Saved as LOC - 222_223.json
# Querying page:  223
# Saved as LOC - 223_224.json
# Querying page:  224
# Saved as LOC - 224_225.json
# Querying page:  225
# Saved as LOC - 225_226.json
# Querying page:  226
# Saved as LOC - 226_227.json
# Querying page:  227
# Saved as LOC - 227_228.json
# Querying page:  228
# Saved as LOC - 228_229.json
# Querying page:  229
# Saved as LOC - 229_230.json
# Querying page:  230
# Saved as LOC - 230_231.json
# Querying page:  231
# Saved as LOC - 231_232.json
# Querying page:  232
# Saved as LOC - 232_233.json
# Querying page:  233
# Saved as LOC - 233_234.json
# Querying page:  234
# Saved as LOC - 234_235.json
# Querying page:  235
# Saved as LOC - 235_236.json
# Querying page:  236
# Saved as LOC - 236_237.json
# Querying page:  237
# Saved as LOC - 237_238.json
# Querying page:  238
# Saved as LOC - 238_239.json
# Querying page:  239
# Saved as LOC - 239_240.json
# Querying page:  240
# Saved as LOC - 240_241.json
# Querying page:  241
# Saved as LOC - 241_242.json
# Querying page:  242
# Saved as LOC - 242_243.json
# Querying page:  243
# Saved as LOC - 243_244.json
# Querying page:  244
# Saved as LOC - 244_245.json
# Querying page:  245
# Saved as LOC - 245_246.json
# Querying page:  246
# Saved as LOC - 246_247.json
# Querying page:  247
# Saved as LOC - 247_248.json
# Querying page:  248
# Saved as LOC - 248_249.json
# Querying page:  249
# Saved as LOC - 249_250.json
# Querying page:  250
# Saved as LOC - 250_251.json
# Querying page:  251
# Saved as LOC - 251_252.json
# Querying page:  252
# Saved as LOC - 252_253.json
# Querying page:  253
# Saved as LOC - 253_254.json
# Querying page:  254
# Saved as LOC - 254_255.json
# Querying page:  255
# Saved as LOC - 255_256.json
# Querying page:  256
# Saved as LOC - 256_257.json
# Querying page:  257
# Saved as LOC - 257_258.json
# Querying page:  258
# Saved as LOC - 258_259.json
# Querying page:  259
# Saved as LOC - 259_260.json
# Querying page:  260
# Saved as LOC - 260_261.json
# Querying page:  261
# Saved as LOC - 261_262.json
# Querying page:  262
# Saved as LOC - 262_263.json
# Querying page:  263
# Saved as LOC - 263_264.json
# Querying page:  264
# Saved as LOC - 264_265.json
# Querying page:  265
# Saved as LOC - 265_266.json
# Querying page:  266
# Saved as LOC - 266_267.json
# Querying page:  267
# Saved as LOC - 267_268.json
# Querying page:  268
# Saved as LOC - 268_269.json
# Querying page:  269
# Saved as LOC - 269_270.json
# Querying page:  270
# Saved as LOC - 270_271.json
# Querying page:  271
# Saved as LOC - 271_272.json
# Querying page:  272
# Saved as LOC - 272_273.json
# Querying page:  273
# Saved as LOC - 273_274.json
# Querying page:  274
# Saved as LOC - 274_275.json
# Querying page:  275
# Saved as LOC - 275_276.json
# Querying page:  276
# Saved as LOC - 276_277.json
# Querying page:  277
# Saved as LOC - 277_278.json
# Querying page:  278
# Saved as LOC - 278_279.json
# Querying page:  279
# Saved as LOC - 279_280.json
# Querying page:  280
# Saved as LOC - 280_281.json
# Querying page:  281
# Saved as LOC - 281_282.json
# Querying page:  282
# Saved as LOC - 282_283.json
# Querying page:  283
# Saved as LOC - 283_284.json
# Querying page:  284
# Saved as LOC - 284_285.json
# Querying page:  285
# Saved as LOC - 285_286.json
# Querying page:  286
# Saved as LOC - 286_287.json
# Querying page:  287
# Saved as LOC - 287_288.json
# Querying page:  288
# Saved as LOC - 288_289.json
# Querying page:  289
# Saved as LOC - 289_290.json
# Querying page:  290
# Saved as LOC - 290_291.json
# Querying page:  291
# Saved as LOC - 291_292.json
# Querying page:  292
# Saved as LOC - 292_293.json
# Querying page:  293
# Saved as LOC - 293_294.json
# Querying page:  294
# Saved as LOC - 294_295.json
# Querying page:  295
# Saved as LOC - 295_296.json
# Querying page:  296
# Saved as LOC - 296_297.json
# Querying page:  297
# Saved as LOC - 297_298.json
# Querying page:  298
# Saved as LOC - 298_299.json
# Querying page:  299
# Saved as LOC - 299_300.json
# Querying page:  300
# Saved as LOC - 300_301.json
# Querying page:  301
# Saved as LOC - 301_302.json
# Querying page:  302
# Saved as LOC - 302_303.json
# Querying page:  303
# Saved as LOC - 303_304.json
# Querying page:  304
# Saved as LOC - 304_305.json
# Querying page:  305
# Saved as LOC - 305_306.json
# Querying page:  306
# Saved as LOC - 306_307.json
# Querying page:  307
# Saved as LOC - 307_308.json
# Querying page:  308
# Saved as LOC - 308_309.json
# Querying page:  309
# Saved as LOC - 309_310.json
# Querying page:  310
# Saved as LOC - 310_311.json
# Querying page:  311
# Saved as LOC - 311_312.json
# Querying page:  312
# Saved as LOC - 312_313.json
# Querying page:  313
# Saved as LOC - 313_314.json
# Querying page:  314
# Saved as LOC - 314_315.json
# Querying page:  315
# Saved as LOC - 315_316.json
# Querying page:  316
# Saved as LOC - 316_317.json
# Querying page:  317
# Saved as LOC - 317_318.json
# Querying page:  318
# Saved as LOC - 318_319.json
# Querying page:  319
# Saved as LOC - 319_320.json
